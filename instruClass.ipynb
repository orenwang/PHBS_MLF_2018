# %%
import fastai
from fastai import *
from fastai.vision import *
from fastai.tabular import *  # Quick access to tabular functionality
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Features: 20 MFCCs, 20 first-derivative of MFCCs, 5 Spectrals

# %%
usecols_21 = ['MFCC01', 'MFCC02', 'MFCC03', 'MFCC04', 'MFCC05', 'MFCC06', 'MFCC07', 'MFCC08', 'MFCC09', 'MFCC10', 'MFCC11', 'MFCC12', 'MFCC13', 'MFCC14', 'MFCC15', 'MFCC16', 'MFCC17', 'MFCC18', 'MFCC19', 'MFCC20', 'Class']
usecols_41 = ['MFCC01', 'MFCC02', 'MFCC03', 'MFCC04', 'MFCC05', 'MFCC06', 'MFCC07', 'MFCC08', 'MFCC09', 'MFCC10', 'MFCC11', 'MFCC12', 'MFCC13', 'MFCC14', 'MFCC15', 'MFCC16', 'MFCC17', 'MFCC18', 'MFCC19', 'MFCC20', 'MFCC_delta01', 'MFCC_delta02', 'MFCC_delta03', 'MFCC_delta04', 'MFCC_delta05', 'MFCC_delta06', 'MFCC_delta07', 'MFCC_delta08', 'MFCC_delta09', 'MFCC_delta10', 'MFCC_delta11', 'MFCC_delta12', 'MFCC_delta13', 'MFCC_delta14', 'MFCC_delta15', 'MFCC_delta16', 'MFCC_delta17', 'MFCC_delta18', 'MFCC_delta19', 'MFCC_delta20', 'Class']
usecols_41 = ['MFCC01', 'MFCC02', 'MFCC03', 'MFCC04', 'MFCC05', 'MFCC06', 'MFCC07', 'MFCC08', 'MFCC09', 'MFCC10', 'MFCC11', 'MFCC12', 'MFCC13', 'MFCC14', 'MFCC15', 'MFCC16', 'MFCC17', 'MFCC18', 'MFCC19', 'MFCC20', 'MFCC_delta01', 'MFCC_delta02', 'MFCC_delta03', 'MFCC_delta04', 'MFCC_delta05', 'MFCC_delta06', 'MFCC_delta07', 'MFCC_delta08', 'MFCC_delta09', 'MFCC_delta10', 'MFCC_delta11', 'MFCC_delta12', 'MFCC_delta13', 'MFCC_delta14', 'MFCC_delta15', 'MFCC_delta16', 'MFCC_delta17', 'MFCC_delta18', 'MFCC_delta19', 'MFCC_delta20', 'Class']

# %%
path = '/root'
df = pd.read_csv('/root/msec_mfcc.csv', usecols = usecols_21)
train_df, valid_df = train_test_split(df)
train_df.head()
# Out:
#          MFCC01      MFCC02     MFCC03     MFCC04     MFCC05     MFCC06  \
# 640 -334.491148   72.452235  -1.855719  45.490209   8.509799  22.965464
# 401 -435.620516  173.158483  23.048999  20.094498  33.183891  16.466300
# 419 -428.169620  121.059603  34.053661  50.618372  30.182472  18.004367
# 257 -615.123301   45.152853  17.098481  33.864624  19.318294   4.057864
# 352 -289.164090  108.582924 -27.837405  27.288107  12.464848  17.655069
#
#         MFCC07     MFCC08     MFCC09     MFCC10  ...       MFCC12    MFCC13  \
# 640  10.711662  15.543619   4.051817  18.249475  ...     8.861721  5.922755
# 401   9.334225  18.745841  24.682602  18.018081  ...     3.176173  5.520040
# 419  11.097981  13.907704   6.838403  11.367124  ...     7.444451 -1.518161
# 257   2.932960   5.021419   2.343462 -11.983820  ...     1.833921 -1.987464
# 352  18.352352  18.228073   8.673469  15.291455  ...    11.088995  1.986346
#
#         MFCC14    MFCC15    MFCC16     MFCC17     MFCC18     MFCC19  \
# 640   0.659132 -1.745376  2.032357 -16.238413  -6.343080 -12.833542
# 401  11.568924  8.063676  2.936240  -5.679601 -12.246373  -5.828032
# 419   4.652521 -2.742319 -1.504913  -2.905291  -0.465806  -3.066190
# 257  -0.057790  1.692193 -7.716143 -16.921008 -11.420027  -7.351461
# 352   6.539307  3.749945 -6.918532   0.146928   3.220367   1.516984
#
#         MFCC20  Class
# 640  -3.054858      3
# 401  10.838343      2
# 419   0.904551      2
# 257 -10.716023      1
# 352   9.159979      2
#
# [5 rows x 21 columns]

# %%
path = '/root'
dep_var = 'Class'
#cat_names = ['Class']
data = TabularDataBunch.from_df(path, train_df, valid_df, dep_var, 
                                tfms=[FillMissing, Categorify], cat_names=None)

# %%
learn = get_tabular_learner(data, layers=[2,2], metrics=accuracy)
learn.fit(8, 1e-2)
# Out:
# Total time: 00:01
# epoch  train_loss  valid_loss  accuracy
# 1      1.472218    1.383953    0.346667  (00:00)
# 2      1.433244    1.323888    0.320000  (00:00)
# 3      1.389021    1.269023    0.293333  (00:00)
# 4      1.345945    1.217730    0.293333  (00:00)
# 5      1.302038    1.175382    0.288889  (00:00)
# 6      1.262074    1.152098    0.284444  (00:00)
# 7      1.230010    1.143774    0.302222  (00:00)
# 8      1.203959    1.133308    0.306667  (00:00)
